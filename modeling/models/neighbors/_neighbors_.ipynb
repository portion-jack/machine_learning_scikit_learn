# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.neighbors import RadiusNeighborsClassifier, RadiusNeighborsRegressor

# %%
pd.DataFrame(KNeighborsClassifier().get_params(),index=['params']).transpose()
# Out:
#                   params
# algorithm           auto
# leaf_size             30
# metric         minkowski
# metric_params       None
# n_jobs              None
# n_neighbors            5
# p                      2
# weights          uniform

# %%
pd.DataFrame(KNeighborsRegressor().get_params(),index=['params']).transpose()
# Out:
#                   params
# algorithm           auto
# leaf_size             30
# metric         minkowski
# metric_params       None
# n_jobs              None
# n_neighbors            5
# p                      2
# weights          uniform

# %%
pd.DataFrame(RadiusNeighborsClassifier().get_params(),index=['params']).transpose()
# Out:
#                   params
# algorithm           auto
# leaf_size             30
# metric         minkowski
# metric_params       None
# n_jobs              None
# outlier_label       None
# p                      2
# radius               1.0
# weights          uniform

# %%
pd.DataFrame(RadiusNeighborsRegressor().get_params(),index=['params']).transpose()
# Out:
#                   params
# algorithm           auto
# leaf_size             30
# metric         minkowski
# metric_params       None
# n_jobs              None
# p                      2
# radius               1.0
# weights          uniform
