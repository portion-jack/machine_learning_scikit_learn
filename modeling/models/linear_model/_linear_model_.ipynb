# %%
import pandas as pd
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.linear_model import LogisticRegression

# %%
pd.DataFrame(LinearRegression().get_params(),index=['params']).transpose()
# Out:
#                    params
# copy_X               True
# fit_intercept        True
# n_jobs               None
# normalize      deprecated
# positive            False

# %%
pd.DataFrame(Ridge().get_params(),index=['params']).transpose()
# Out:
#                    params
# alpha                 1.0
# copy_X               True
# fit_intercept        True
# max_iter             None
# normalize      deprecated
# positive            False
# random_state         None
# solver               auto
# tol                 0.001

# %%
pd.DataFrame(Lasso().get_params(),index=['params']).transpose()
# Out:
#                    params
# alpha                 1.0
# copy_X               True
# fit_intercept        True
# max_iter             1000
# normalize      deprecated
# positive            False
# precompute          False
# random_state         None
# selection          cyclic
# tol                0.0001
# warm_start          False

# %%
pd.DataFrame(LogisticRegression().get_params(),index=['params']).transpose()
# Out:
#                    params
# C                     1.0
# class_weight         None
# dual                False
# fit_intercept        True
# intercept_scaling       1
# l1_ratio             None
# max_iter              100
# multi_class          auto
# n_jobs               None
# penalty                l2
# random_state         None
# solver              lbfgs
# tol                0.0001
# verbose                 0
# warm_start          False
