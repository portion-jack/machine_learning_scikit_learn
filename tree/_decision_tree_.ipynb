# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.tree import ExtraTreeClassifier, ExtraTreeRegressor

# %%
pd.DataFrame(DecisionTreeClassifier().get_params(),index=['params']).transpose()
# Out:
#                          params
# ccp_alpha                   0.0
# class_weight               None
# criterion                  gini
# max_depth                  None
# max_features               None
# max_leaf_nodes             None
# min_impurity_decrease       0.0
# min_samples_leaf              1
# min_samples_split             2
# min_weight_fraction_leaf    0.0
# random_state               None
# splitter                   best

# %%
pd.DataFrame(DecisionTreeRegressor().get_params(),index=['params']).transpose()
# Out:
#                                  params
# ccp_alpha                           0.0
# criterion                 squared_error
# max_depth                          None
# max_features                       None
# max_leaf_nodes                     None
# min_impurity_decrease               0.0
# min_samples_leaf                      1
# min_samples_split                     2
# min_weight_fraction_leaf            0.0
# random_state                       None
# splitter                           best

# %%
pd.DataFrame(ExtraTreeClassifier().get_params(),index=['params']).transpose()
# Out:
#                           params
# ccp_alpha                    0.0
# class_weight                None
# criterion                   gini
# max_depth                   None
# max_features                sqrt
# max_leaf_nodes              None
# min_impurity_decrease        0.0
# min_samples_leaf               1
# min_samples_split              2
# min_weight_fraction_leaf     0.0
# random_state                None
# splitter                  random

# %%
pd.DataFrame(ExtraTreeRegressor().get_params(),index=['params']).transpose()
# Out:
#                                  params
# ccp_alpha                           0.0
# criterion                 squared_error
# max_depth                          None
# max_features                        1.0
# max_leaf_nodes                     None
# min_impurity_decrease               0.0
# min_samples_leaf                      1
# min_samples_split                     2
# min_weight_fraction_leaf            0.0
# random_state                       None
# splitter                         random
