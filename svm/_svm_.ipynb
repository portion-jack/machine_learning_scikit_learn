# %%
import pandas as pd
from sklearn.svm import LinearSVC,LinearSVR
from sklearn.svm import SVC,SVR
from sklearn.svm import NuSVC,NuSVR

# %%
[LinearSVC,LinearSVR,SVC,SVR,NuSVC,NuSVR]

# %%
pd.DataFrame(LinearSVC().get_params(),index=['params']).transpose()
# Out:
#                           params
# C                            1.0
# class_weight                None
# dual                        True
# fit_intercept               True
# intercept_scaling              1
# loss               squared_hinge
# max_iter                    1000
# multi_class                  ovr
# penalty                       l2
# random_state                None
# tol                       0.0001
# verbose                        0

# %%
pd.DataFrame(LinearSVR().get_params(),index=['params']).transpose()
# Out:
#                                 params
# C                                  1.0
# dual                              True
# epsilon                            0.0
# fit_intercept                     True
# intercept_scaling                  1.0
# loss               epsilon_insensitive
# max_iter                          1000
# random_state                      None
# tol                             0.0001
# verbose                              0

# %%
pd.DataFrame(SVC().get_params(),index=['params']).transpose()
# Out:
#                         params
# C                          1.0
# break_ties               False
# cache_size                 200
# class_weight              None
# coef0                      0.0
# decision_function_shape    ovr
# degree                       3
# gamma                    scale
# kernel                     rbf
# max_iter                    -1
# probability              False
# random_state              None
# shrinking                 True
# tol                      0.001
# verbose                  False

# %%
pd.DataFrame(SVR().get_params(),index=['params']).transpose()
# Out:
#            params
# C             1.0
# cache_size    200
# coef0         0.0
# degree          3
# epsilon       0.1
# gamma       scale
# kernel        rbf
# max_iter       -1
# shrinking    True
# tol         0.001
# verbose     False

# %%
pd.DataFrame(NuSVC().get_params(),index=['params']).transpose()
# Out:
#                         params
# break_ties               False
# cache_size                 200
# class_weight              None
# coef0                      0.0
# decision_function_shape    ovr
# degree                       3
# gamma                    scale
# kernel                     rbf
# max_iter                    -1
# nu                         0.5
# probability              False
# random_state              None
# shrinking                 True
# tol                      0.001
# verbose                  False

# %%
pd.DataFrame(NuSVR().get_params(),index=['params']).transpose()
# Out:
#            params
# C             1.0
# cache_size    200
# coef0         0.0
# degree          3
# gamma       scale
# kernel        rbf
# max_iter       -1
# nu            0.5
# shrinking    True
# tol         0.001
# verbose     False
